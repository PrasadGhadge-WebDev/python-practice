# %%
s = "Instagram"
print(s[2:6])
print(s[0:9])
print(s[0:100])
print(s[0:len(s)])
# Out:
# stag
# Instagram
# Instagram
# Instagram

# %% [markdown]
# ### Step value in String
# ### Synatax :- Start_Index

# %%
s= "Instagram"
print(s[4:-8:-1])
print(s[4:1:-1])
print(s[::-1])
print(s[-1 : -len(s) : -1])
# Out:
# ats
# ats
# margatsnI
# margatsn
