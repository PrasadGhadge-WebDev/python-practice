# %% [markdown]
# # Build in Functions
# ### print
#     --> Used to display msg or var on console
# ### type
#     --> This function return data type of variable
# ### id
#     --> This function returns memory address of variable
# ### input
#     --> This function is used to take input from user

# %%
a = 10
print(a)
print(type(a))
print(id(a))
# Out:
# 10
# <class 'int'>
# 140707780421016
