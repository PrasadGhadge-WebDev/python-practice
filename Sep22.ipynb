# %% [markdown]
# ### String Practice

# %% [markdown]
# ### Find gram  In string

# %%
s = "Instagram"
char4 = s[-1]
char1 = s[-2]
char2 = s[-3]
char3 = s[-4]

print(char3,char2,char1, char4)
# Out:
# g r a m

# %% [markdown]
# ### Find First And Last Char In Sring

# %%
s1 = "Python Programming"
first_char = s1[0]
last_char = s1[-1]
print(first_char, last_char)

print(s1[0],s1[-1])
# Out:
# P g
# P g
