# %%
a = 111
print(a)
print(type(a))
# Out:
# 111
# <class 'int'>

# %%
b = 123.321
print(b)
print(type(b))
# Out:
# 123.321
# <class 'float'>

# %%
name = input("Enter your name: ")
print("Hello, " + name + "!")
# Out:
# Hello,  Prasad!

# %%
num1 = int(input("Enter First Number: "))
num2 = int(input("Enter Second Number: "))

print(num1 + num2)
# Out:
# 30
