# %%
s = "Prasad Ghadage"

print(s[0:6])
print(s[1:6])
print(s[0:5])
print(s[2:6])
print(s[7:14])
print(s[8:14])
print(s[7:12])
print(s[:6])
print(s[:5])
print(s[7:])
print(s[8:])
print(s[:])
print(s[0:14:2])
print(s[1:14:2])
print(s[0:14:3])
print(s[1:14:3])
print(s[5:0:-1])
print(s[13:6:-1])
print(s[::-1])
print(s[14:2:-2])
# Out:
# Prasad
# rasad
# Prasa
# asad
# Ghadage
# hadage
# Ghada
# Prasad
# Prasa
# Ghadage
# hadage
# Prasad Ghadage
# Paa hdg
# rsdGaae
# Ps ag
# raGde
# dasar
# egadahG
# egadahG dasarP
# eaaGds
